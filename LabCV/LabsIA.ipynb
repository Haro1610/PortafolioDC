# %% [markdown]
# # Computer vission

# %%
# establecer credenciales de comunicacion con azure 
key = 'ca8af9e5611b4d2bbd94a5dc9facdae9'
endpoint = 'https://cv-dr1.cognitiveservices.azure.com/'

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint,CognitiveServicesCredentials(key))

# %%
import vision
import os

# %matplotlib inline

image_path="../Ejercicios sesiones live/data/vision/Akira-Wallpaper-Akira-1988-Hd-Wallpapers-backgrounds-.jpg"

image_stream = open(image_path,'rb')
description = client.describe_image_in_stream(image_stream)
print(description)

vision.show_image_caption(image_path,description)
# Out:
# {'additional_properties': {}, 'tags': ['transport', 'light', 'dark'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x00000297643C6950>], 'request_id': '0628e063-d41f-41c1-92c7-854130d8a87b', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x00000297643C4790>, 'model_version': '2021-05-01'}

# %%
image_path="../Ejercicios sesiones live/data/vision/Akira-Wallpaper-Akira-1988-Hd-Wallpapers-backgrounds-.jpg"
image_stream = open(image_path,'rb')
description = client.describe_image_in_stream(image_stream)
print(description)

vision.show_image_caption(image_path,description)
# Out:
# {'additional_properties': {}, 'tags': ['transport', 'light', 'dark'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x000002976226F820>], 'request_id': 'bcfac2af-f19c-416e-88a0-46d246891b41', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x0000029765F25BD0>, 'model_version': '2021-05-01'}

# %% [markdown]
# # Face API

# %%
# !pip install azure-cognitiveservices-vision-face
# Out:
# ...
#      -------------------------------------- 67.7/67.7 KB 610.8 kB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\haaro\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
key_face_api = 'a3498bbb8b6646fe91be60f338300d6b'
endpoint_face_api = 'https://aaron-lab02.cognitiveservices.azure.com/'

# %%
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint_face_api,CognitiveServicesCredentials(key_face_api))

# %%
import faces
import os
# %matplotlib inline

# %%
image_path = '../Ejercicios sesiones live/data/vision/familia.jpg'

image_stream = open(image_path,'rb')

detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path,detected_faces, show_id=True)

# %%
image_path = '../Ejercicios sesiones live/data/vision/familia.jpg'

image_stream = open(image_path,'rb')

atributes = ['age','emotion']
detected_faces = client.face.detect_with_stream(image=image_stream, return_face_attributes=atributes)

faces.show_face_attributes(image_path,detected_faces)
